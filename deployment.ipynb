# %%
from joblib import dump,load
import numpy as np
model=load('breast_cancer.joblib')

# %%
features=np.array([[ 0.39382017,  0.11364754,  1.96775431,  0.1946302 ,  0.00754035,
        1.31121806,  1.08195125,  0.96021455,  0.67033541,  1.84521868,
        1.1327751 , -0.11175406, -0.30887663,  0.00937117, -0.16000529,
       -0.4493909 ,  0.91896637,  0.51076713, -0.15264175, -0.23255072,
        0.59972124,  0.25116933,  1.9188801 ,  0.5070188 ,  0.11385275,
        1.57241433,  2.64643036,  2.10984728,  0.8813547 ,  2.10770156,
        2.84218422]])
model.predict(features)
# Out:
# array([1], dtype=int64)

# %%
feat=np.array([[-0.24347658, -0.35622404, -1.42668426, -0.41980844, -0.39669657,
       -1.88033181, -1.27051655, -0.83750779, -0.96623692, -1.73825044,
       -0.95699478, -0.87499905, -1.35110521, -0.83974282, -0.57943486,
       -0.73528439, -0.65415522, -0.53274862, -0.95462506, -0.52934685,
       -0.61727296, -0.55212923, -1.654086  , -0.59933047, -0.53402165,
       -1.53065126, -0.89555395, -0.75660704, -0.93323277, -0.93592679,
       -0.82089914]])
model.predict(feat)
# Out:
# array([0], dtype=int64)
